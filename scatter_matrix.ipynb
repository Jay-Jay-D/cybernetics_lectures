# %%
import pandas as pd
import numpy as np
import seaborn

# %%
symbols = ["AAPL", "AMZN", "BAC", "DDD", "JPM", "MSFT", "MSTR", "SPY", "TSLA", "XOM" ]
data = get_pricing(
    symbols,
    fields='close_price',
    start_date='2014-01-01',
    end_date = '2015-07-31',
    frequency='minute'
)

# %%
# Change the columns name for plotting.
data.columns = [data.columns[i].symbol for i in range(len(data.columns))]

# %%
pd.scatter_matrix(data, diagonal='kde', figsize=(20, 20), alpha=0.5);

# %% [markdown]
# The price levels are very noisy, So let's try with a log difference.

# %%
data = np.log(data/data.shift())
pd.scatter_matrix(data, diagonal='kde', figsize=(20, 20), alpha=0.5);
